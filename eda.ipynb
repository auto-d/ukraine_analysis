# %%
import fiona
import pandas as pd
import geopandas
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
fud = geopandas.read_file('export/shapefile/fud.shp')

# %%
fud.head()
# Out:
#       f_lat     f_lng  f_bright  f_scan  f_track       date f_acqtime f_sat  \
# 0  48.59764  38.02026    338.81    0.38     0.36 2023-03-04      1015     N
# 1  48.40023  37.89245    321.99    0.40     0.37 2024-06-19      2324   N20
# 2  47.09460  37.55670    314.00    1.30     1.10 2022-03-22      1012  Aqua
# 3  47.83153  36.82017    303.57    0.48     0.48 2022-08-30      0016     N
# 4  48.32475  37.82122    302.68    0.59     0.70 2024-07-11      2222   N21
#
#   f_inst f_conf  ...              a_type                     a_event  \
# 0  VIIRS      n  ...  Political violence                     Battles
# 1  VIIRS      n  ...  Political violence                     Battles
# 2  MODIS      n  ...  Political violence  Explosions/Remote violence
# 3  VIIRS      n  ...  Political violence  Explosions/Remote violence
# 4  VIIRS      n  ...  Political violence                     Battles
#
#                           a_subevent   a_location    a_lat    a_lng a_geoprec  \
# ...

# %%
fud.plot()
# Out:
# <Axes: >

# %%
fud2 = geopandas.read_file('export/geopackage/fud.gpkg')

# %%
fud2.head()
# Out:
#       f_lat     f_lng  f_bright  f_scan  f_track       date f_acqtime f_sat  \
# 0  48.59764  38.02026    338.81    0.38     0.36 2023-03-04      1015     N
# 1  48.40023  37.89245    321.99    0.40     0.37 2024-06-19      2324   N20
# 2  47.09460  37.55670    314.00    1.30     1.10 2022-03-22      1012  Aqua
# 3  47.83153  36.82017    303.57    0.48     0.48 2022-08-30      0016     N
# 4  48.32475  37.82122    302.68    0.59     0.70 2024-07-11      2222   N21
#
#   f_inst f_conf  ...              a_type                     a_event  \
# 0  VIIRS      n  ...  Political violence                     Battles
# 1  VIIRS      n  ...  Political violence                     Battles
# 2  MODIS      n  ...  Political violence  Explosions/Remote violence
# 3  VIIRS      n  ...  Political violence  Explosions/Remote violence
# 4  VIIRS      n  ...  Political violence                     Battles
#
#                           a_subevent   a_location    a_lat    a_lng a_geoprec  \
# ...

# %%
fud2.columns
# Out:
# Index(['f_lat', 'f_lng', 'f_bright', 'f_scan', 'f_track', 'date', 'f_acqtime',
#        'f_sat', 'f_inst', 'f_conf', 'f_bright31', 'f_frp', 'f_daynight',
#        'f_datetime', 'a_index', 'a_event_id', 'a_type', 'a_event',
#        'a_subevent', 'a_location', 'a_lat', 'a_lng', 'a_geoprec', 'h_adm_en',
#        'h_adm_ua', 'geometry'],
#       dtype='object')
